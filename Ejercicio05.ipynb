-- %% [raw]
-- a) incrementarLista xs = map suma xs

-- %%
incrementarLista :: [Int] -> [Int]
incrementarLista = map (\x -> x + 1)
-- Out:
-- Line 2: Avoid lambda using `infix`
-- Found:
-- (\ x -> x + 1)
-- Why not:
-- (+ 1)

-- %% [raw]
-- b) filtrarPares xs = filter even xs

-- %%
filtrarPares :: [Int] -> [Int]
filtrarPares = filter (\x -> x `mod` 2 == 1)

-- %% [raw]
-- c) sumarTuplas xs = ...

-- %%
sumarTuplas :: [(Int, Int)] -> [Int]
sumarTuplas = map (\(a, b) -> a + b)
-- Out:
-- Line 2: Use uncurry
-- Found:
-- \ (a, b) -> a + b
-- Why not:
-- uncurry (+)
