-- %% [raw]
-- take 5 (map (*2) [1..])

-- %% [markdown]
-- a) Genera una lista infinita, saca los primeros 5 valores y los duplica.

-- %%
-- b)
take 5 (map (*2) [1..])
-- Out:
-- [2,4,6,8,10]

-- %% [markdown]
-- **¿Por qué [1..] no causa un ciclo infinito?**
-- Porque con la evaluación perezosa solo evalúa lo necesario; en vez de generar toda la lista infinita, solo genera los primeros 5 valores.

-- %%
misterio :: Int -> Int -> Int
misterio x y = if x > 10 then y * 2 else x + y

-- %% [raw]
-- Paso 1: Se evalúa el primer argumento para la condición de x > 10:
--     5 + 7 = 12
--     misterio 12 (3*4)
-- Paso 2: Se evalúa la condición de 12 > 10 --> True.
--     Como es True, toma la condición de y * 2.
-- Paso 3: Se evalúa el siguiente argumento.
--     4 * 3 = 12
-- Paso 4: Se calcula y * 2 = 12 * 2 = 24.
